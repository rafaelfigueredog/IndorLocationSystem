# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
experimento = {}
listaDeMedidas =[10, 100, 210, 240]
sizeMedidas = len(listaDeMedidas)
for i in range(sizeMedidas):
    medida = listaDeMedidas[i]
    nomeDoAquivo = "dados/experimento3/" + str(medida) + 'cm.txt'
    arquivo = open(nomeDoAquivo, 'r')
    dados = arquivo.read()
    stringSize = len(dados)
    dados = dados[1:stringSize-1]
    dados = dados.split(', ')
    dados = dados[0:120]
    sizeDados = len(dados)
    for j in range(sizeDados):
        dados[j] = int(dados[j])
    coluna = str(medida) + 'cm'
    experimento[coluna] = dados
experimento = pd.DataFrame(data=experimento)
experimento
# Out:
#      10cm  100cm  210cm  240cm
# 0     -43    -74    -68    -65
# 1     -45    -58    -65    -70
# 2     -41    -59    -66    -74
# 3     -48    -61    -66    -72
# 4     -48    -59    -65    -72
# 5     -42    -60    -69    -73
# 6     -48    -59    -65    -70
# 7     -51    -65    -69    -71
# 8     -47    -62    -71    -69
# 9     -51    -62    -64    -70
# 10    -41    -59    -64    -70
# 11    -53    -64    -66    -72
# 12    -48    -63    -63    -70
# 13    -53    -62    -65    -70
# 14    -56    -62    -67    -70
# 15    -43    -63    -65    -70
# 16    -43    -63    -68    -71
# 17    -41    -61    -69    -71
# 18    -45    -59    -66    -74
# 19    -44    -60    -66    -73
# 20    -46    -61    -68    -72
# 21    -49    -62    -68    -71
# 22    -43    -59    -68    -72
# 23    -43    -61    -65    -73
# 24    -43    -62    -72    -73
# 25    -41    -64    -67    -72
# 26    -41    -65    -69    -72
# 27    -42    -63    -63    -72
# 28    -42    -59    -69    -72
# 29    -43    -60    -66    -73
# ..    ...    ...    ...    ...
# 90    -43    -63    -66    -71
# 91    -41    -70    -68    -71
# 92    -43    -61    -69    -71
# 93    -43    -69    -69    -71
# 94    -41    -74    -71    -71
# 95    -43    -67    -69    -71
# 96    -43    -59    -68    -71
# 97    -43    -60    -75    -73
# 98    -41    -59    -68    -71
# 99    -43    -63    -76    -73
# 100   -43    -60    -77    -71
# 101   -43    -60    -73    -74
# 102   -43    -60    -70    -71
# 103   -45    -64    -68    -71
# 104   -44    -59    -68    -73
# 105   -43    -62    -67    -71
# 106   -41    -71    -68    -71
# 107   -44    -62    -68    -71
# 108   -43    -62    -69    -71
# 109   -43    -63    -68    -67
# 110   -43    -62    -71    -74
# 111   -44    -62    -67    -71
# 112   -41    -63    -71    -71
# 113   -43    -69    -75    -71
# 114   -43    -66    -70    -71
# 115   -41    -66    -69    -71
# 116   -45    -59    -66    -71
# 117   -43    -67    -69    -71
# 118   -45    -67    -69    -71
# 119   -45    -61    -73    -72
#
# [120 rows x 4 columns]

# %%
# Medidas de Tendência Central e Medidas de Dispersão

dispesao = {'Medidas': ['Média', 'Variância','Desvio Padrão', 'Amplitude']}

for i in list(experimento.columns):
    dispesao[i] = []

for i in list(experimento.columns):
    
    #calculando
    media = experimento[i].mean()
    variancia =  experimento[i].var()
    desvioPadrao = experimento[i].std()
    amplitude = experimento[i].max() - experimento[i].min()
    
    #adicionando
    dispesao[i].append(round(media, 2))
    dispesao[i].append(round(variancia, 2)) 
    dispesao[i].append(round(desvioPadrao, 2)) 
    dispesao[i].append(amplitude) 

dispesao = pd.DataFrame(data=dispesao)

# %%
dispesao
# Out:
#          Medidas   10cm  100cm  210cm  240cm
# 0          Média -43.78 -63.48 -68.78 -71.80
# 1      Variância   7.90  20.24  13.25   1.99
# 2  Desvio Padrão   2.81   4.50   3.64   1.41
# 3      Amplitude  16.00  27.00  18.00   9.00

# %%
experimento.describe()
# Out:
#              10cm       100cm       210cm       240cm
# count  120.000000  120.000000  120.000000  120.000000
# mean   -43.783333  -63.483333  -68.783333  -71.800000
# std      2.811092    4.498335    3.639612    1.411835
# min    -56.000000  -83.000000  -81.000000  -74.000000
# 25%    -44.000000  -66.250000  -69.000000  -73.000000
# 50%    -43.000000  -62.000000  -68.000000  -72.000000
# 75%    -42.000000  -60.000000  -66.000000  -71.000000
# max    -40.000000  -56.000000  -63.000000  -65.000000

# %%
# library & dataset

import seaborn as sns
df = experimento

for i in list(experimento.columns):
    sns.kdeplot(df[i], shade=True)
    plt.show()

# %%
df = experimento

for i in list(experimento.columns):
# Hist only
    sns.distplot( a=df[i], hist=True, kde=False, rug=False )
    plt.show()

# %%
# use the plot function
plt.plot(experimento['240cm'])

# %%
plt.plot(experimento['10cm'])

# %%
plt.plot(experimento['100cm'])

# %%
plt.plot(experimento['210cm'])
