# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
experimento = {}
listaDeMedidas =[10, 20, 30, 40, 50, 60, 70]
sizeMedidas = len(listaDeMedidas)
for i in range(sizeMedidas):
    medida = listaDeMedidas[i]
    nomeDoAquivo = "dados/experimento2/" + str(medida) + 'cm.txt'
    arquivo = open(nomeDoAquivo, 'r')
    dados = arquivo.read()
    stringSize = len(dados)
    dados = dados[1:stringSize-1]
    dados = dados.split(', ')
    dados = dados[0:120]
    sizeDados = len(dados)
    for j in range(sizeDados):
        dados[j] = int(dados[j])
    coluna = str(medida) + 'cm'
    experimento[coluna] = dados
experimento = pd.DataFrame(data=experimento)
experimento
# Out:
#      10cm  20cm  30cm  40cm  50cm  60cm  70cm
# 0     -50   -43   -42   -45   -60   -58   -70
# 1     -51   -41   -41   -46   -60   -58   -71
# 2     -51   -42   -41   -47   -61   -58   -63
# 3     -50   -42   -41   -48   -60   -66   -63
# 4     -50   -42   -43   -48   -60   -66   -64
# 5     -62   -43   -43   -46   -61   -67   -64
# 6     -51   -42   -41   -48   -60   -57   -72
# 7     -50   -43   -42   -45   -60   -58   -64
# 8     -50   -44   -41   -47   -57   -57   -73
# 9     -51   -44   -41   -48   -60   -67   -63
# 10    -50   -43   -43   -46   -60   -57   -64
# 11    -50   -41   -41   -45   -60   -57   -64
# 12    -50   -41   -42   -47   -61   -65   -73
# 13    -50   -42   -41   -48   -61   -58   -64
# 14    -50   -42   -41   -45   -61   -58   -73
# 15    -50   -44   -43   -48   -61   -58   -74
# 16    -50   -43   -43   -48   -60   -58   -64
# 17    -50   -42   -41   -48   -60   -65   -75
# 18    -50   -43   -43   -48   -61   -65   -63
# 19    -50   -43   -41   -48   -61   -57   -64
# 20    -50   -43   -43   -48   -58   -57   -63
# 21    -50   -43   -42   -45   -61   -57   -63
# 22    -51   -41   -42   -47   -60   -65   -74
# 23    -50   -42   -43   -48   -61   -58   -64
# 24    -49   -43   -43   -48   -58   -58   -64
# 25    -50   -42   -43   -48   -61   -57   -64
# 26    -50   -43   -41   -45   -58   -64   -74
# 27    -50   -42   -43   -45   -61   -57   -74
# 28    -50   -42   -43   -48   -55   -58   -64
# 29    -51   -42   -43   -48   -58   -65   -64
# ..    ...   ...   ...   ...   ...   ...   ...
# 90    -56   -42   -41   -47   -58   -63   -64
# 91    -52   -42   -43   -47   -58   -63   -64
# 92    -52   -42   -43   -45   -62   -57   -64
# 93    -52   -42   -41   -45   -58   -58   -73
# 94    -56   -42   -41   -45   -58   -63   -73
# 95    -51   -42   -43   -47   -61   -58   -72
# 96    -52   -43   -43   -45   -62   -58   -64
# 97    -51   -42   -43   -47   -61   -58   -64
# 98    -51   -41   -41   -48   -58   -58   -64
# 99    -53   -42   -41   -46   -58   -58   -64
# 100   -51   -42   -42   -45   -60   -58   -64
# 101   -50   -42   -42   -48   -62   -62   -64
# 102   -51   -43   -43   -46   -60   -58   -65
# 103   -51   -43   -43   -45   -58   -58   -64
# 104   -52   -42   -41   -48   -60   -59   -64
# 105   -52   -43   -43   -46   -60   -63   -64
# 106   -51   -42   -42   -46   -60   -62   -64
# 107   -52   -42   -41   -48   -62   -62   -64
# 108   -51   -42   -42   -46   -62   -62   -65
# 109   -50   -42   -43   -46   -58   -62   -74
# 110   -51   -42   -42   -45   -62   -58   -65
# 111   -53   -42   -42   -46   -58   -62   -65
# 112   -52   -43   -42   -48   -62   -62   -74
# 113   -53   -43   -42   -46   -60   -58   -65
# 114   -50   -43   -43   -47   -62   -58   -65
# 115   -53   -43   -41   -48   -58   -59   -64
# 116   -52   -43   -43   -48   -58   -58   -64
# 117   -51   -43   -43   -46   -58   -58   -74
# 118   -49   -43   -43   -48   -58   -58   -74
# 119   -50   -43   -41   -46   -61   -62   -64
#
# [120 rows x 7 columns]

# %%
# Medidas de Tendência Central e Medidas de Dispersão

dispesao = {'Medidas': ['Média', 'Variância','Desvio Padrão', 'Amplitude']}

for i in list(experimento.columns):
    dispesao[i] = []

for i in list(experimento.columns):
    
    #calculando
    media = experimento[i].mean()
    variancia =  experimento[i].var()
    desvioPadrao = experimento[i].std()
    amplitude = experimento[i].max() - experimento[i].min()
    
    #adicionando
    dispesao[i].append(round(media, 2))
    dispesao[i].append(round(variancia, 2)) 
    dispesao[i].append(round(desvioPadrao, 2)) 
    dispesao[i].append(amplitude) 

dispesao = pd.DataFrame(data=dispesao)

# %%
dispesao
# Out:
#          Medidas   10cm   20cm   30cm   40cm   50cm   60cm   70cm
# 0          Média -50.83 -42.42 -42.08 -46.69 -59.73 -59.75 -66.52
# 1      Variância   2.51   0.46   0.79   1.37   2.77   9.20  18.47
# 2  Desvio Padrão   1.58   0.68   0.89   1.17   1.67   3.03   4.30
# 3      Amplitude  17.00   3.00   2.00   3.00   7.00  12.00  13.00

# %%
experimento.describe()
# Out:
#              10cm        20cm        30cm        40cm        50cm        60cm  \
# count  120.000000  120.000000  120.000000  120.000000  120.000000  120.000000
# mean   -50.833333  -42.416667  -42.075000  -46.691667  -59.725000  -59.750000
# std      1.584236    0.680871    0.890307    1.172484    1.665076    3.032735
# min    -62.000000  -44.000000  -43.000000  -48.000000  -62.000000  -67.000000
# 25%    -51.000000  -43.000000  -43.000000  -48.000000  -61.000000  -62.000000
# 50%    -51.000000  -42.000000  -42.000000  -47.000000  -60.000000  -58.000000
# 75%    -50.000000  -42.000000  -41.000000  -46.000000  -58.000000  -58.000000
# max    -45.000000  -41.000000  -41.000000  -45.000000  -55.000000  -55.000000
#
#              70cm
# count  120.000000
# mean   -66.516667
# std      4.297710
# min    -76.000000
# 25%    -72.000000
# 50%    -64.000000
# 75%    -64.000000
# max    -63.000000

# %%
# library & dataset

import seaborn as sns
df = experimento

for i in list(experimento.columns):
    sns.kdeplot(df[i], shade=True)
    plt.show()

# %%
df = experimento

for i in list(experimento.columns):
# Hist only
    sns.distplot( a=df[i], hist=True, kde=False, rug=False )
    plt.show()
