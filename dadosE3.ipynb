# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
experimento = {}
for i in range(1,25):
    medida = i * 10
    if medida != 10 and medida != 240: 
        continue
    
    nomeDoAquivo = "dados/experimento3/" + str(medida) + 'cm.txt'
    arquivo = open(nomeDoAquivo, 'r')
    dados = arquivo.read()
    stringSize = len(dados)
    dados = dados[1:stringSize-1]
    dados = dados.split(', ')
    dados = dados[0:120]
    sizeDados = len(dados)
    for i in range(sizeDados):
        dados[i] = int(dados[i])
    coluna = str(medida) + 'cm'
    experimento[coluna] = dados
experimento = pd.DataFrame(data=experimento)
experimento
# Out:
#      10cm  240cm
# 0     -43    -65
# 1     -45    -70
# 2     -41    -74
# 3     -48    -72
# 4     -48    -72
# 5     -42    -73
# 6     -48    -70
# 7     -51    -71
# 8     -47    -69
# 9     -51    -70
# 10    -41    -70
# 11    -53    -72
# 12    -48    -70
# 13    -53    -70
# 14    -56    -70
# 15    -43    -70
# 16    -43    -71
# 17    -41    -71
# 18    -45    -74
# 19    -44    -73
# 20    -46    -72
# 21    -49    -71
# 22    -43    -72
# 23    -43    -73
# 24    -43    -73
# 25    -41    -72
# 26    -41    -72
# 27    -42    -72
# 28    -42    -72
# 29    -43    -73
# ..    ...    ...
# 90    -43    -71
# 91    -41    -71
# 92    -43    -71
# 93    -43    -71
# 94    -41    -71
# 95    -43    -71
# 96    -43    -71
# 97    -43    -73
# 98    -41    -71
# 99    -43    -73
# 100   -43    -71
# 101   -43    -74
# 102   -43    -71
# 103   -45    -71
# 104   -44    -73
# 105   -43    -71
# 106   -41    -71
# 107   -44    -71
# 108   -43    -71
# 109   -43    -67
# 110   -43    -74
# 111   -44    -71
# 112   -41    -71
# 113   -43    -71
# 114   -43    -71
# 115   -41    -71
# 116   -45    -71
# 117   -43    -71
# 118   -45    -71
# 119   -45    -72
#
# [120 rows x 2 columns]

# %%
# Medidas de Tendência Central e Medidas de Dispersão

dispesao = {'Medidas': ['Média', 'Variância','Desvio Padrão', 'Amplitude']}

for i in list(experimento.columns):
    dispesao[i] = []

for i in list(experimento.columns):
    
    #calculando
    media = experimento[i].mean()
    variancia =  experimento[i].var()
    desvioPadrao = experimento[i].std()
    amplitude = experimento[i].max() - experimento[i].min()
    
    #adicionando
    dispesao[i].append(round(media, 2))
    dispesao[i].append(round(variancia, 2)) 
    dispesao[i].append(round(desvioPadrao, 2)) 
    dispesao[i].append(amplitude) 

dispesao = pd.DataFrame(data=dispesao)

# %%
dispesao
# Out:
#          Medidas   10cm  240cm
# 0          Média -43.78 -71.80
# 1      Variância   7.90   1.99
# 2  Desvio Padrão   2.81   1.41
# 3      Amplitude  16.00   9.00

# %%
experimento.describe()
# Out:
#              10cm       240cm
# count  120.000000  120.000000
# mean   -43.783333  -71.800000
# std      2.811092    1.411835
# min    -56.000000  -74.000000
# 25%    -44.000000  -73.000000
# 50%    -43.000000  -72.000000
# 75%    -42.000000  -71.000000
# max    -40.000000  -65.000000

# %%
# library & dataset

import seaborn as sns
df = experimento

for i in list(experimento.columns):
    sns.kdeplot(df[i], shade=True)
    plt.show()

# %%
df = experimento

for i in list(experimento.columns):
# Hist only
    sns.distplot( a=df[i], hist=True, kde=False, rug=False )
    plt.show()

# %%
# use the plot function
plt.plot(experimento['240cm'])

# %%
plt.plot(experimento['10cm'])
