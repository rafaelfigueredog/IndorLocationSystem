# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
experimento = {}
for i in range(24,25):
    medida = i * 10
    nomeDoAquivo = "dados/experimento3/" + str(medida) + 'cm.txt'
    arquivo = open(nomeDoAquivo, 'r')
    dados = arquivo.read()
    stringSize = len(dados)
    dados = dados[1:stringSize-1]
    dados = dados.split(', ')
    dados = dados[0:120]
    sizeDados = len(dados)
    for i in range(sizeDados):
        dados[i] = int(dados[i])
    coluna = str(medida) + 'cm'
    experimento[coluna] = dados
experimento = pd.DataFrame(data=experimento)
experimento
# Out:
#      240cm
# 0      -65
# 1      -70
# 2      -74
# 3      -72
# 4      -72
# 5      -73
# 6      -70
# 7      -71
# 8      -69
# 9      -70
# 10     -70
# 11     -72
# 12     -70
# 13     -70
# 14     -70
# 15     -70
# 16     -71
# 17     -71
# 18     -74
# 19     -73
# 20     -72
# 21     -71
# 22     -72
# 23     -73
# 24     -73
# 25     -72
# 26     -72
# 27     -72
# 28     -72
# 29     -73
# ..     ...
# 90     -71
# 91     -71
# 92     -71
# 93     -71
# 94     -71
# 95     -71
# 96     -71
# 97     -73
# 98     -71
# 99     -73
# 100    -71
# 101    -74
# 102    -71
# 103    -71
# 104    -73
# 105    -71
# 106    -71
# 107    -71
# 108    -71
# 109    -67
# 110    -74
# 111    -71
# 112    -71
# 113    -71
# 114    -71
# 115    -71
# 116    -71
# 117    -71
# 118    -71
# 119    -72
#
# [120 rows x 1 columns]

# %%
# Medidas de Tendência Central e Medidas de Dispersão

dispesao = {'Medidas': ['Média', 'Variância','Desvio Padrão', 'Amplitude']}

for i in list(experimento.columns):
    dispesao[i] = []

for i in list(experimento.columns):
    
    #calculando
    media = experimento[i].mean()
    variancia =  experimento[i].var()
    desvioPadrao = experimento[i].std()
    amplitude = experimento[i].max() - experimento[i].min()
    
    #adicionando
    dispesao[i].append(round(media, 2))
    dispesao[i].append(round(variancia, 2)) 
    dispesao[i].append(round(desvioPadrao, 2)) 
    dispesao[i].append(amplitude) 

dispesao = pd.DataFrame(data=dispesao)

# %%
dispesao
# Out:
#          Medidas  240cm
# 0          Média -71.80
# 1      Variância   1.99
# 2  Desvio Padrão   1.41
# 3      Amplitude   9.00

# %%
experimento.describe()
# Out:
#             240cm
# count  120.000000
# mean   -71.800000
# std      1.411835
# min    -74.000000
# 25%    -73.000000
# 50%    -72.000000
# 75%    -71.000000
# max    -65.000000

# %%
# library & dataset



import seaborn as sns
df = experimento

for i in list(experimento.columns):
    sns.kdeplot(df[i], shade=True)
    plt.show()

# %%
df = experimento

for i in list(experimento.columns):
# Hist only
    sns.distplot( a=df[i], hist=True, kde=False, rug=False )
    plt.show()

# %%
fig, eixos = plt.subplots(nrows=3, ncols=3, figsize=(20,20))

colunas = list(experimento.columns)

colunas[0] = eixos[0][0].plot(experimento[colunas[0]], scalex=True, scaley=True)
eixos[0][0].set_title('10cm')

colunas[1] = eixos[0][1].plot(experimento[colunas[1]], scalex=True, scaley=True)
eixos[0][1].set_title('20cm')

colunas[2] = eixos[0][2].plot(experimento[colunas[2]], scalex=True, scaley=True)
eixos[0][2].set_title('30cm')

colunas[3] = eixos[1][0].plot(experimento[colunas[3]], scalex=True, scaley=True)
eixos[1][0].set_title('40cm')

colunas[4] = eixos[1][1].plot(experimento[colunas[4]], scalex=True, scaley=True)
eixos[1][1].set_title('50cm')

colunas[5] = eixos[1][2].plot(experimento[colunas[5]], scalex=True, scaley=True)
eixos[1][2].set_title('60cm')

colunas[6] = eixos[2][0].plot(experimento[colunas[6]], scalex=True, scaley=True)
eixos[2][0].set_title('70cm')

colunas[7] = eixos[2][1].plot(experimento[colunas[7]], scalex=True, scaley=True)
eixos[2][1].set_title('80cm')

colunas[8] = eixos[2][2].plot(experimento[colunas[8]], scalex=True, scaley=True)
eixos[2][2].set_title('90cm')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-838df8999af1> in <module>
#       6 eixos[0][0].set_title('10cm')
#       7
# ----> 8 colunas[1] = eixos[0][1].plot(experimento[colunas[1]], scalex=True, scaley=True)
#       9 eixos[0][1].set_title('20cm')
#      10
#
# IndexError: list index out of range
